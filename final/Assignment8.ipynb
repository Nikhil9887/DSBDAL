# %%
import nltk
import re
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('average-perceptron-tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nikhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading average-perceptron-tagger: Package 'average-
# [nltk_data]     perceptron-tagger' not found in index
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nikhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nikhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Nikhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
with open('doc1.txt', 'r') as f:
    doc1 = f.read()

doc1 = re.sub('[\W_]+', ' ', doc1)

with open('doc2.txt', 'r') as f:
    doc2 = f.read()

doc2 = re.sub('[\W_]+', ' ', doc2)

# %%
doc1
# Out:
# 'Sustainable fashion is gaining momentum as consumers prioritize eco friendly choices From ethically sourced materials to fair labor practices the industry is adapting to meet the demand for environmentally conscious clothing Designers are increasingly incorporating recycled fabrics and sustainable production methods setting a new standard for ethical fashion '

# %%
doc2
# Out:
# 'Paris Milan London and New York are renowned as the fashion capitals hosting iconic fashion weeks that set global trends These events showcase the creativity and innovation of designers from around the world The intersection of culture art and commerce in these cities defines the fashion landscape influencing styles and shaping the industry s direction '

# %%
word_tokens_1 = nltk.word_tokenize(doc1)

# %%
word_tokens_1
# Out:
# ['Sustainable',
#  'fashion',
#  'is',
#  'gaining',
#  'momentum',
#  'as',
#  'consumers',
#  'prioritize',
#  'eco',
#  'friendly',
#  'choices',
#  'From',
#  'ethically',
#  'sourced',
#  'materials',
#  'to',
#  'fair',
#  'labor',
#  'practices',
#  'the',
#  'industry',
#  'is',
#  'adapting',
#  'to',
#  'meet',
#  'the',
#  'demand',
#  'for',
#  'environmentally',
#  'conscious',
#  'clothing',
#  'Designers',
#  'are',
#  'increasingly',
#  'incorporating',
#  'recycled',
#  'fabrics',
#  'and',
#  'sustainable',
#  'production',
#  'methods',
#  'setting',
#  'a',
#  'new',
#  'standard',
#  'for',
#  'ethical',
#  'fashion']

# %%
word_tokens_2 = nltk.word_tokenize(doc2)

# %%
word_tokens_2
# Out:
# ['Paris',
#  'Milan',
#  'London',
#  'and',
#  'New',
#  'York',
#  'are',
#  'renowned',
#  'as',
#  'the',
#  'fashion',
#  'capitals',
#  'hosting',
#  'iconic',
#  'fashion',
#  'weeks',
#  'that',
#  'set',
#  'global',
#  'trends',
#  'These',
#  'events',
#  'showcase',
#  'the',
#  'creativity',
#  'and',
#  'innovation',
#  'of',
#  'designers',
#  'from',
#  'around',
#  'the',
#  'world',
#  'The',
#  'intersection',
#  'of',
#  'culture',
#  'art',
#  'and',
#  'commerce',
#  'in',
#  'these',
#  'cities',
#  'defines',
#  'the',
#  'fashion',
#  'landscape',
#  'influencing',
#  'styles',
#  'and',
#  'shaping',
#  'the',
#  'industry',
#  's',
#  'direction']

# %%
all_tokens = word_tokens_1 + word_tokens_2
all_tokens
# Out:
# ['Sustainable',
#  'fashion',
#  'is',
#  'gaining',
#  'momentum',
#  'as',
#  'consumers',
#  'prioritize',
#  'eco',
#  'friendly',
#  'choices',
#  'From',
#  'ethically',
#  'sourced',
#  'materials',
#  'to',
#  'fair',
#  'labor',
#  'practices',
#  'the',
#  'industry',
#  'is',
#  'adapting',
#  'to',
#  'meet',
#  'the',
#  'demand',
#  'for',
#  'environmentally',
#  'conscious',
#  'clothing',
#  'Designers',
#  'are',
#  'increasingly',
#  'incorporating',
#  'recycled',
#  'fabrics',
#  'and',
#  'sustainable',
#  'production',
#  'methods',
#  'setting',
#  'a',
#  'new',
#  'standard',
#  'for',
#  'ethical',
#  'fashion',
#  'Paris',
#  'Milan',
#  'London',
#  'and',
#  'New',
#  'York',
#  'are',
#  'renowned',
#  'as',
#  'the',
#  'fashion',
#  'capitals',
#  'hosting',
#  'iconic',
#  'fashion',
#  'weeks',
#  'that',
#  'set',
#  'global',
#  'trends',
#  'These',
#  'events',
#  'showcase',
#  'the',
#  'creativity',
#  'and',
#  'innovation',
#  'of',
#  'designers',
#  'from',
#  'around',
#  'the',
#  'world',
#  'The',
#  'intersection',
#  'of',
#  'culture',
#  'art',
#  'and',
#  'commerce',
#  'in',
#  'these',
#  'cities',
#  'defines',
#  'the',
#  'fashion',
#  'landscape',
#  'influencing',
#  'styles',
#  'and',
#  'shaping',
#  'the',
#  'industry',
#  's',
#  'direction']

# %%
sent_tokenize = nltk.sent_tokenize(doc1)
sent_tokenize
# Out:
# ['Sustainable fashion is gaining momentum as consumers prioritize eco friendly choices From ethically sourced materials to fair labor practices the industry is adapting to meet the demand for environmentally conscious clothing Designers are increasingly incorporating recycled fabrics and sustainable production methods setting a new standard for ethical fashion']

# %%
stop_words = set(nltk.corpus.stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
all_tokens = [token for token in all_tokens if token not in stop_words]
all_tokens
# Out:
# ['Sustainable',
#  'fashion',
#  'gaining',
#  'momentum',
#  'consumers',
#  'prioritize',
#  'eco',
#  'friendly',
#  'choices',
#  'From',
#  'ethically',
#  'sourced',
#  'materials',
#  'fair',
#  'labor',
#  'practices',
#  'industry',
#  'adapting',
#  'meet',
#  'demand',
#  'environmentally',
#  'conscious',
#  'clothing',
#  'Designers',
#  'increasingly',
#  'incorporating',
#  'recycled',
#  'fabrics',
#  'sustainable',
#  'production',
#  'methods',
#  'setting',
#  'new',
#  'standard',
#  'ethical',
#  'fashion',
#  'Paris',
#  'Milan',
#  'London',
#  'New',
#  'York',
#  'renowned',
#  'fashion',
#  'capitals',
#  'hosting',
#  'iconic',
#  'fashion',
#  'weeks',
#  'set',
#  'global',
#  'trends',
#  'These',
#  'events',
#  'showcase',
#  'creativity',
#  'innovation',
#  'designers',
#  'around',
#  'world',
#  'The',
#  'intersection',
#  'culture',
#  'art',
#  'commerce',
#  'cities',
#  'defines',
#  'fashion',
#  'landscape',
#  'influencing',
#  'styles',
#  'shaping',
#  'industry',
#  'direction']

# %%
tags = nltk.pos_tag(all_tokens)
print(tags)
# Out:
# [('Sustainable', 'JJ'), ('fashion', 'NN'), ('gaining', 'VBG'), ('momentum', 'NN'), ('consumers', 'NNS'), ('prioritize', 'VBP'), ('eco', 'NNS'), ('friendly', 'JJ'), ('choices', 'NNS'), ('From', 'IN'), ('ethically', 'RB'), ('sourced', 'VBN'), ('materials', 'NNS'), ('fair', 'JJ'), ('labor', 'NN'), ('practices', 'NNS'), ('industry', 'NN'), ('adapting', 'VBG'), ('meet', 'JJ'), ('demand', 'NN'), ('environmentally', 'RB'), ('conscious', 'JJ'), ('clothing', 'NN'), ('Designers', 'NNP'), ('increasingly', 'RB'), ('incorporating', 'VBG'), ('recycled', 'VBN'), ('fabrics', 'NNS'), ('sustainable', 'JJ'), ('production', 'NN'), ('methods', 'NNS'), ('setting', 'VBG'), ('new', 'JJ'), ('standard', 'JJ'), ('ethical', 'JJ'), ('fashion', 'NN'), ('Paris', 'NNP'), ('Milan', 'NNP'), ('London', 'NNP'), ('New', 'NNP'), ('York', 'NNP'), ('renowned', 'JJ'), ('fashion', 'NN'), ('capitals', 'NNS'), ('hosting', 'VBG'), ('iconic', 'JJ'), ('fashion', 'NN'), ('weeks', 'NNS'), ('set', 'VBD'), ('global', 'JJ'), ('trends', 'NNS'), ('These', 'DT'), ('events', 'NNS'), ('showcase', 'VBP'), ('creativity', 'NN'), ('innovation', 'NN'), ('designers', 'NNS'), ('around', 'IN'), ('world', 'NN'), ('The', 'DT'), ('intersection', 'NN'), ('culture', 'NN'), ('art', 'NN'), ('commerce', 'NN'), ('cities', 'NNS'), ('defines', 'VBZ'), ('fashion', 'NN'), ('landscape', 'NN'), ('influencing', 'VBG'), ('styles', 'NNS'), ('shaping', 'VBG'), ('industry', 'NN'), ('direction', 'NN')]

# %%
# lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in all_tokens]
lemmatized_tokens
# Out:
# ['Sustainable',
#  'fashion',
#  'gaining',
#  'momentum',
#  'consumer',
#  'prioritize',
#  'eco',
#  'friendly',
#  'choice',
#  'From',
#  'ethically',
#  'sourced',
#  'material',
#  'fair',
#  'labor',
#  'practice',
#  'industry',
#  'adapting',
#  'meet',
#  'demand',
#  'environmentally',
#  'conscious',
#  'clothing',
#  'Designers',
#  'increasingly',
#  'incorporating',
#  'recycled',
#  'fabric',
#  'sustainable',
#  'production',
#  'method',
#  'setting',
#  'new',
#  'standard',
#  'ethical',
#  'fashion',
#  'Paris',
#  'Milan',
#  'London',
#  'New',
#  'York',
#  'renowned',
#  'fashion',
#  'capital',
#  'hosting',
#  'iconic',
#  'fashion',
#  'week',
#  'set',
#  'global',
#  'trend',
#  'These',
#  'event',
#  'showcase',
#  'creativity',
#  'innovation',
#  'designer',
#  'around',
#  'world',
#  'The',
#  'intersection',
#  'culture',
#  'art',
#  'commerce',
#  'city',
#  'defines',
#  'fashion',
#  'landscape',
#  'influencing',
#  'style',
#  'shaping',
#  'industry',
#  'direction']

# %%
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in all_tokens]
stemmed_tokens
# Out:
# ['sustain',
#  'fashion',
#  'gain',
#  'momentum',
#  'consum',
#  'priorit',
#  'eco',
#  'friendli',
#  'choic',
#  'from',
#  'ethic',
#  'sourc',
#  'materi',
#  'fair',
#  'labor',
#  'practic',
#  'industri',
#  'adapt',
#  'meet',
#  'demand',
#  'environment',
#  'consciou',
#  'cloth',
#  'design',
#  'increasingli',
#  'incorpor',
#  'recycl',
#  'fabric',
#  'sustain',
#  'product',
#  'method',
#  'set',
#  'new',
#  'standard',
#  'ethic',
#  'fashion',
#  'pari',
#  'milan',
#  'london',
#  'new',
#  'york',
#  'renown',
#  'fashion',
#  'capit',
#  'host',
#  'icon',
#  'fashion',
#  'week',
#  'set',
#  'global',
#  'trend',
#  'these',
#  'event',
#  'showcas',
#  'creativ',
#  'innov',
#  'design',
#  'around',
#  'world',
#  'the',
#  'intersect',
#  'cultur',
#  'art',
#  'commerc',
#  'citi',
#  'defin',
#  'fashion',
#  'landscap',
#  'influenc',
#  'style',
#  'shape',
#  'industri',
#  'direct']

# %%
word_tokens_1

def tf(tokens):
    term_freq = {}
    for token in tokens:
        if token not in term_freq:
            term_freq[token] = tokens.count(token) / len(tokens)

    return term_freq

doc1_tf = tf(word_tokens_1)
print(doc1_tf)
# Out:
# {'Sustainable': 0.020833333333333332, 'fashion': 0.041666666666666664, 'is': 0.041666666666666664, 'gaining': 0.020833333333333332, 'momentum': 0.020833333333333332, 'as': 0.020833333333333332, 'consumers': 0.020833333333333332, 'prioritize': 0.020833333333333332, 'eco': 0.020833333333333332, 'friendly': 0.020833333333333332, 'choices': 0.020833333333333332, 'From': 0.020833333333333332, 'ethically': 0.020833333333333332, 'sourced': 0.020833333333333332, 'materials': 0.020833333333333332, 'to': 0.041666666666666664, 'fair': 0.020833333333333332, 'labor': 0.020833333333333332, 'practices': 0.020833333333333332, 'the': 0.041666666666666664, 'industry': 0.020833333333333332, 'adapting': 0.020833333333333332, 'meet': 0.020833333333333332, 'demand': 0.020833333333333332, 'for': 0.041666666666666664, 'environmentally': 0.020833333333333332, 'conscious': 0.020833333333333332, 'clothing': 0.020833333333333332, 'Designers': 0.020833333333333332, 'are': 0.020833333333333332, 'increasingly': 0.020833333333333332, 'incorporating': 0.020833333333333332, 'recycled': 0.020833333333333332, 'fabrics': 0.020833333333333332, 'and': 0.020833333333333332, 'sustainable': 0.020833333333333332, 'production': 0.020833333333333332, 'methods': 0.020833333333333332, 'setting': 0.020833333333333332, 'a': 0.020833333333333332, 'new': 0.020833333333333332, 'standard': 0.020833333333333332, 'ethical': 0.020833333333333332}

# %%
import math
def idf_calculate():
    N = 2
    alltokens = word_tokens_1 + word_tokens_2
    idf = {}
    for token in alltokens:
        f = 0
        if (token in word_tokens_1):
            f+=1
        if (token in word_tokens_2):
            f+=1
        # idf[token] = math.log(N/f)
        if (f==0):
            idf[token] = math.log(N/(f+1))
        else:
            idf[token] = math.log(N/f)

    return idf

idf = idf_calculate()
print(idf)
# Out:
# {'Sustainable': 0.6931471805599453, 'fashion': 0.0, 'is': 0.6931471805599453, 'gaining': 0.6931471805599453, 'momentum': 0.6931471805599453, 'as': 0.0, 'consumers': 0.6931471805599453, 'prioritize': 0.6931471805599453, 'eco': 0.6931471805599453, 'friendly': 0.6931471805599453, 'choices': 0.6931471805599453, 'From': 0.6931471805599453, 'ethically': 0.6931471805599453, 'sourced': 0.6931471805599453, 'materials': 0.6931471805599453, 'to': 0.6931471